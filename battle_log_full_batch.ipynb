# %%
from battle_log_final import battle_log_from_json

# %%
json_path = r"./scraped_ids/clash_royale_uniform.json"

# %%
csv_path_part1 = r"./scrapped_data/semi_data_trail_part1.csv"
csv_path_part2 = r"./scrapped_data/semi_data_trail_part2.csv"
csv_path_part3 = r"./scrapped_data/semi_data_trail_part3.csv"
csv_path_part4 = r"./scrapped_data/semi_data_trail_part4.csv"
csv_path_part5 = r"./scrapped_data/semi_data_trail_part5.csv"
csv_path_part6 = r"./scrapped_data/semi_data_trail_part6.csv"
csv_path_part7 = r"./scrapped_data/semi_data_trail_part7.csv"
csv_path_part8 = r"./scrapped_data/semi_data_trail_part8.csv"
csv_path_part9 = r"./scrapped_data/semi_data_trail_part9.csv"
csv_path_part10 = r"./scrapped_data/semi_data_trail_part10.csv"

# %%
battle_log_from_json(json_path, csv_path_part1, index_tuple=(0, 4999))

# %%
battle_log_from_json(json_path, csv_path_part2, index_tuple=(5000, 9999))

# %%
battle_log_from_json(json_path, csv_path_part3, index_tuple=(10000, 14999))

# %%
battle_log_from_json(json_path, csv_path_part4, index_tuple=(15000, 19999))

# %%
battle_log_from_json(json_path, csv_path_part5, index_tuple=(20000, 24999))

# %%
battle_log_from_json(json_path, csv_path_part6, index_tuple=(25000, 29999))

# %%
battle_log_from_json(json_path, csv_path_part7, index_tuple=(30000, 34999))

# %%
battle_log_from_json(json_path, csv_path_part8, index_tuple=(35000, 39999))

# %%
battle_log_from_json(json_path, csv_path_part9, index_tuple=(40000, 44999))

# %%
battle_log_from_json(json_path, csv_path_part10, index_tuple=(45000, 49999))
